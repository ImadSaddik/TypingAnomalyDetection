# %% [markdown]
# ## Read all data

# %%
training_data = [
    {
        "timestamp": "2025-07-03T22:25:27.383Z",
        "features": {
            "holdTimeMean": 117.08888888928212,
            "holdTimeStandardDeviation": 92.68943012852175,
            "pressPressMean": 183.4470588235075,
            "pressPressStandardDeviation": 82.9403258195698,
            "releaseReleaseMean": 160.4470588235075,
            "releaseReleaseStandardDeviation": 100.67415332190842,
            "releasePressMean": 64.57058823492159,
            "releasePressStandardDeviation": 94.257518033792,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:25:37.382Z",
        "features": {
            "holdTimeMean": 91.02499999987104,
            "holdTimeStandardDeviation": 35.15900506626477,
            "pressPressMean": 190.64313725488006,
            "pressPressStandardDeviation": 126.63483763130077,
            "releaseReleaseMean": 190.10196078433563,
            "releaseReleaseStandardDeviation": 129.68660299383995,
            "releasePressMean": 98.91372549033487,
            "releasePressStandardDeviation": 134.6274474533896,
            "backspaceCount": 3,
        },
    },
    {
        "timestamp": "2025-07-03T22:25:47.382Z",
        "features": {
            "holdTimeMean": 76.98913043478261,
            "holdTimeStandardDeviation": 24.62445242037131,
            "pressPressMean": 218.87555555556384,
            "pressPressStandardDeviation": 166.02921587837673,
            "releaseReleaseMean": 219.56666666666666,
            "releaseReleaseStandardDeviation": 171.0790221451302,
            "releasePressMean": 141.93111111111938,
            "releasePressStandardDeviation": 170.38855571643992,
            "backspaceCount": 1,
        },
    },
    {
        "timestamp": "2025-07-03T22:25:57.382Z",
        "features": {
            "holdTimeMean": 84.6180000000447,
            "holdTimeStandardDeviation": 30.76034214673273,
            "pressPressMean": 197.06938775510963,
            "pressPressStandardDeviation": 124.39620540174538,
            "releaseReleaseMean": 196.1857142857067,
            "releaseReleaseStandardDeviation": 133.2133767681362,
            "releasePressMean": 112.31020408157943,
            "releasePressStandardDeviation": 136.69787282675537,
            "backspaceCount": 3,
        },
    },
    {
        "timestamp": "2025-07-03T22:26:07.382Z",
        "features": {
            "holdTimeMean": 83.38490566041953,
            "holdTimeStandardDeviation": 20.855440133711706,
            "pressPressMean": 185.15000000001433,
            "pressPressStandardDeviation": 79.42040410544182,
            "releaseReleaseMean": 184.5903846154061,
            "releaseReleaseStandardDeviation": 81.47414905710592,
            "releasePressMean": 101.66730769229336,
            "releasePressStandardDeviation": 83.43313095925818,
            "backspaceCount": 1,
        },
    },
    {
        "timestamp": "2025-07-03T22:26:17.382Z",
        "features": {
            "holdTimeMean": 97.87249999996274,
            "holdTimeStandardDeviation": 73.17770428124598,
            "pressPressMean": 249.71025641028507,
            "pressPressStandardDeviation": 151.63193108182898,
            "releaseReleaseMean": 249.82564102566968,
            "releaseReleaseStandardDeviation": 182.82014273158046,
            "releasePressMean": 151.52051282057968,
            "releasePressStandardDeviation": 175.36285716601816,
            "backspaceCount": 1,
        },
    },
    {
        "timestamp": "2025-07-03T22:26:27.382Z",
        "features": {
            "holdTimeMean": 202.86326530609963,
            "holdTimeStandardDeviation": 782.4689178317012,
            "pressPressMean": 198.65625,
            "pressPressStandardDeviation": 187.1676321196968,
            "releaseReleaseMean": 197.0166666666822,
            "releaseReleaseStandardDeviation": 1132.5337684758792,
            "releasePressMean": -7.293749999992239,
            "releasePressStandardDeviation": 819.6418398941354,
            "backspaceCount": 5,
        },
    },
    {
        "timestamp": "2025-07-03T22:26:37.382Z",
        "features": {
            "holdTimeMean": 89.71833333342026,
            "holdTimeStandardDeviation": 25.448102667545854,
            "pressPressMean": 158.72542372879462,
            "pressPressStandardDeviation": 77.41780200080093,
            "releaseReleaseMean": 159.51694915254237,
            "releaseReleaseStandardDeviation": 81.53864569783825,
            "releasePressMean": 69.26271186431207,
            "releasePressStandardDeviation": 84.94751908921472,
            "backspaceCount": 1,
        },
    },
    {
        "timestamp": "2025-07-03T22:26:47.382Z",
        "features": {
            "holdTimeMean": 90.26734693895797,
            "holdTimeStandardDeviation": 44.445103722504015,
            "pressPressMean": 194.19166666665114,
            "pressPressStandardDeviation": 157.37520126007269,
            "releaseReleaseMean": 195.17500000000777,
            "releaseReleaseStandardDeviation": 181.64966691238143,
            "releasePressMean": 104.39166666648816,
            "releasePressStandardDeviation": 167.68009668032263,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:26:57.382Z",
        "features": {
            "holdTimeMean": 79.91333333320088,
            "holdTimeStandardDeviation": 20.314533534693794,
            "pressPressMean": 209.27499999999154,
            "pressPressStandardDeviation": 164.20263449315078,
            "releaseReleaseMean": 209.67272727276114,
            "releaseReleaseStandardDeviation": 165.02340124908304,
            "releasePressMean": 129.54772727288812,
            "releasePressStandardDeviation": 167.30220878559365,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:27:07.382Z",
        "features": {
            "holdTimeMean": 86.2725490195421,
            "holdTimeStandardDeviation": 22.41549534094075,
            "pressPressMean": 194.7460000000149,
            "pressPressStandardDeviation": 148.39136369882638,
            "releaseReleaseMean": 194.63800000000745,
            "releaseReleaseStandardDeviation": 151.91951130217603,
            "releasePressMean": 108.34800000008195,
            "releasePressStandardDeviation": 151.86878767342318,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:27:17.382Z",
        "features": {
            "holdTimeMean": 81.13333333338447,
            "holdTimeStandardDeviation": 21.4627460188284,
            "pressPressMean": 195.46800000000746,
            "pressPressStandardDeviation": 160.89761536022465,
            "releaseReleaseMean": 196.62400000002236,
            "releaseReleaseStandardDeviation": 156.08428199441877,
            "releasePressMean": 114.69599999997764,
            "releasePressStandardDeviation": 160.23838995806182,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:27:27.382Z",
        "features": {
            "holdTimeMean": 82.01111111106972,
            "holdTimeStandardDeviation": 35.44692617392402,
            "pressPressMean": 229.58823529411765,
            "pressPressStandardDeviation": 143.78390418610178,
            "releaseReleaseMean": 229.11176470590428,
            "releaseReleaseStandardDeviation": 171.05558629571925,
            "releasePressMean": 147.80588235300692,
            "releasePressStandardDeviation": 162.68388238637894,
            "backspaceCount": 3,
        },
    },
    {
        "timestamp": "2025-07-03T22:28:27.382Z",
        "features": {
            "holdTimeMean": 135.33333333333334,
            "holdTimeStandardDeviation": 138.38411517739567,
            "pressPressMean": 231.5,
            "pressPressStandardDeviation": 90.9339320590095,
            "releaseReleaseMean": 347.5,
            "releaseReleaseStandardDeviation": 275.77164466275354,
            "releasePressMean": 175.95000000018626,
            "releasePressStandardDeviation": 101.32840174324201,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:28:37.382Z",
        "features": {
            "holdTimeMean": 117.58695652153666,
            "holdTimeStandardDeviation": 175.80195120745202,
            "pressPressMean": 216.5622222221974,
            "pressPressStandardDeviation": 204.8240922538382,
            "releaseReleaseMean": 215.91333333336644,
            "releaseReleaseStandardDeviation": 402.88657020856556,
            "releasePressMean": 98.97777777798474,
            "releasePressStandardDeviation": 288.6508640434719,
            "backspaceCount": 7,
        },
    },
    {
        "timestamp": "2025-07-03T22:28:47.382Z",
        "features": {
            "holdTimeMean": 85.47966101680393,
            "holdTimeStandardDeviation": 27.588464478798965,
            "pressPressMean": 161.2396551724202,
            "pressPressStandardDeviation": 121.62280046461292,
            "releaseReleaseMean": 161.70862068968086,
            "releaseReleaseStandardDeviation": 134.1334322369928,
            "releasePressMean": 75.79137931051183,
            "releasePressStandardDeviation": 131.50624731256974,
            "backspaceCount": 1,
        },
    },
    {
        "timestamp": "2025-07-03T22:28:57.382Z",
        "features": {
            "holdTimeMean": 89.98245614041623,
            "holdTimeStandardDeviation": 28.558837278940715,
            "pressPressMean": 170.23749999998003,
            "pressPressStandardDeviation": 86.44004872005101,
            "releaseReleaseMean": 170.84999999999334,
            "releaseReleaseStandardDeviation": 89.45742918478409,
            "releasePressMean": 80.61964285706303,
            "releasePressStandardDeviation": 94.85319263256127,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:29:07.382Z",
        "features": {
            "holdTimeMean": 90.92745098033372,
            "holdTimeStandardDeviation": 31.999350483576862,
            "pressPressMean": 197.2860000000149,
            "pressPressStandardDeviation": 130.6398898516368,
            "releaseReleaseMean": 197.8039999999851,
            "releaseReleaseStandardDeviation": 135.41708956741365,
            "releasePressMean": 106.45600000005216,
            "releasePressStandardDeviation": 130.89381763034496,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:29:17.382Z",
        "features": {
            "holdTimeMean": 74.71346153838273,
            "holdTimeStandardDeviation": 21.577284977532862,
            "pressPressMean": 182.59411764707343,
            "pressPressStandardDeviation": 99.89832313257499,
            "releaseReleaseMean": 181.95098039215685,
            "releaseReleaseStandardDeviation": 95.71466632153142,
            "releasePressMean": 107.48823529419799,
            "releasePressStandardDeviation": 102.75228201279032,
            "backspaceCount": 6,
        },
    },
    {
        "timestamp": "2025-07-03T22:29:27.382Z",
        "features": {
            "holdTimeMean": 86.95094339605772,
            "holdTimeStandardDeviation": 27.87250245871335,
            "pressPressMean": 186.77884615384616,
            "pressPressStandardDeviation": 173.39901659327137,
            "releaseReleaseMean": 187.09038461537028,
            "releaseReleaseStandardDeviation": 178.80368165225087,
            "releasePressMean": 99.83846153863348,
            "releasePressStandardDeviation": 182.4100757815325,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:29:37.382Z",
        "features": {
            "holdTimeMean": 78.10000000032596,
            "holdTimeStandardDeviation": 12.6943031845085,
            "pressPressMean": 160.48666666671633,
            "pressPressStandardDeviation": 107.46655869673644,
            "releaseReleaseMean": 159.4733333333085,
            "releaseReleaseStandardDeviation": 108.41733168444541,
            "releasePressMean": 81.91333333303531,
            "releasePressStandardDeviation": 109.20154935271779,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:29:57.414Z",
        "features": {
            "holdTimeMean": 100.9,
            "holdTimeStandardDeviation": 62.25798270324978,
            "pressPressMean": 177.79230769231725,
            "pressPressStandardDeviation": 109.83575868824732,
            "releaseReleaseMean": 168.3615384615289,
            "releaseReleaseStandardDeviation": 91.9573917791273,
            "releasePressMean": 76.52307692308648,
            "releasePressStandardDeviation": 95.13199545217044,
            "backspaceCount": 1,
        },
    },
    {
        "timestamp": "2025-07-03T22:30:07.414Z",
        "features": {
            "holdTimeMean": 94.5883333333768,
            "holdTimeStandardDeviation": 42.14633543260065,
            "pressPressMean": 165.02203389828614,
            "pressPressStandardDeviation": 123.93282394480069,
            "releaseReleaseMean": 164.60169491525423,
            "releaseReleaseStandardDeviation": 133.8188089087383,
            "releasePressMean": 69.69999999994948,
            "releasePressStandardDeviation": 132.96942090758296,
            "backspaceCount": 2,
        },
    },
    {
        "timestamp": "2025-07-03T22:30:17.414Z",
        "features": {
            "holdTimeMean": 87.79423076895854,
            "holdTimeStandardDeviation": 21.23794618648197,
            "pressPressMean": 188.21960784315917,
            "pressPressStandardDeviation": 224.59492337967674,
            "releaseReleaseMean": 188.06470588236755,
            "releaseReleaseStandardDeviation": 226.48326633425737,
            "releasePressMean": 100.90000000029949,
            "releasePressStandardDeviation": 226.7054935373949,
            "backspaceCount": 1,
        },
    },
    {
        "timestamp": "2025-07-03T22:30:27.413Z",
        "features": {
            "holdTimeMean": 83.97045454552227,
            "holdTimeStandardDeviation": 29.59074006282834,
            "pressPressMean": 201.73953488373826,
            "pressPressStandardDeviation": 160.75484905610975,
            "releaseReleaseMean": 200.90232558141267,
            "releaseReleaseStandardDeviation": 161.0917418123211,
            "releasePressMean": 117.38372093018924,
            "releasePressStandardDeviation": 163.8739235628118,
            "backspaceCount": 5,
        },
    },
    {
        "timestamp": "2025-07-03T22:30:37.414Z",
        "features": {
            "holdTimeMean": 78.89615384603923,
            "holdTimeStandardDeviation": 25.486828289986637,
            "pressPressMean": 177.55098039214957,
            "pressPressStandardDeviation": 109.0967082409834,
            "releaseReleaseMean": 177.56470588233103,
            "releaseReleaseStandardDeviation": 118.53591156024554,
            "releasePressMean": 98.36666666676163,
            "releasePressStandardDeviation": 117.38130629135435,
            "backspaceCount": 2,
        },
    },
    {
        "timestamp": "2025-07-03T22:30:47.413Z",
        "features": {
            "holdTimeMean": 90.83191489341094,
            "holdTimeStandardDeviation": 42.53789158128042,
            "pressPressMean": 209.50652173910615,
            "pressPressStandardDeviation": 148.94367078755533,
            "releaseReleaseMean": 209.57608695652175,
            "releaseReleaseStandardDeviation": 169.80633568171282,
            "releasePressMean": 118.31956521757756,
            "releasePressStandardDeviation": 163.0384625644461,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:30:57.414Z",
        "features": {
            "holdTimeMean": 93.9775862068837,
            "holdTimeStandardDeviation": 64.78218036084274,
            "pressPressMean": 155.92280701753734,
            "pressPressStandardDeviation": 103.45374918552248,
            "releaseReleaseMean": 155.93157894736188,
            "releaseReleaseStandardDeviation": 166.24721067248979,
            "releasePressMean": 61.9807017543925,
            "releasePressStandardDeviation": 113.42469723278717,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:31:07.413Z",
        "features": {
            "holdTimeMean": 88.48529411759228,
            "holdTimeStandardDeviation": 21.108753495745706,
            "pressPressMean": 276.95454545454544,
            "pressPressStandardDeviation": 395.65106872309656,
            "releaseReleaseMean": 277.5424242424355,
            "releaseReleaseStandardDeviation": 392.002178749057,
            "releasePressMean": 188.6242424242876,
            "releasePressStandardDeviation": 397.46729348936117,
            "backspaceCount": 1,
        },
    },
    {
        "timestamp": "2025-07-03T22:31:17.421Z",
        "features": {
            "holdTimeMean": 106.97368421042829,
            "holdTimeStandardDeviation": 131.6619744080389,
            "pressPressMean": 266.8432432432231,
            "pressPressStandardDeviation": 511.0115032085968,
            "releaseReleaseMean": 266.9297297297398,
            "releaseReleaseStandardDeviation": 599.8673607393907,
            "releasePressMean": 159.10270270277317,
            "releasePressStandardDeviation": 524.6178505913014,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:31:27.754Z",
        "features": {
            "holdTimeMean": 75.4119999999553,
            "holdTimeStandardDeviation": 19.410699798353487,
            "pressPressMean": 153.90833333328678,
            "pressPressStandardDeviation": 96.10746664498289,
            "releaseReleaseMean": 154.98750000004657,
            "releaseReleaseStandardDeviation": 102.52551458713502,
            "releasePressMean": 78.6500000000621,
            "releasePressStandardDeviation": 106.48409556665601,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:32:44.193Z",
        "features": {
            "holdTimeMean": 93.97037037048075,
            "holdTimeStandardDeviation": 54.05734714756033,
            "pressPressMean": 178.84999999998567,
            "pressPressStandardDeviation": 150.45663361913995,
            "releaseReleaseMean": 169.51923076923077,
            "releaseReleaseStandardDeviation": 160.21548494247688,
            "releasePressMean": 84.75769230759201,
            "releasePressStandardDeviation": 161.9273248664142,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:32:54.193Z",
        "features": {
            "holdTimeMean": 97.02857142859804,
            "holdTimeStandardDeviation": 51.12052769326001,
            "pressPressMean": 428.58461538458675,
            "pressPressStandardDeviation": 1061.7067060838292,
            "releaseReleaseMean": 429.5,
            "releaseReleaseStandardDeviation": 1060.2990380071872,
            "releasePressMean": 330.7846153845581,
            "releasePressStandardDeviation": 1062.7763608004373,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:34:44.739Z",
        "features": {
            "holdTimeMean": 97.20727272731337,
            "holdTimeStandardDeviation": 38.286458560327965,
            "pressPressMean": 173.77777777777777,
            "pressPressStandardDeviation": 98.30224026049471,
            "releaseReleaseMean": 169.18703703703014,
            "releaseReleaseStandardDeviation": 97.84233957611308,
            "releasePressMean": 76.07592592588453,
            "releasePressStandardDeviation": 100.7071261559387,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:34:54.739Z",
        "features": {
            "holdTimeMean": 82.91034482759905,
            "holdTimeStandardDeviation": 28.059783856196198,
            "pressPressMean": 172.48947368421707,
            "pressPressStandardDeviation": 151.51378612930145,
            "releaseReleaseMean": 172.35263157894084,
            "releaseReleaseStandardDeviation": 150.1937963635955,
            "releasePressMean": 89.37543859649776,
            "releasePressStandardDeviation": 150.12550854041632,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:35:04.739Z",
        "features": {
            "holdTimeMean": 94.53999999985099,
            "holdTimeStandardDeviation": 91.17430708660885,
            "pressPressMean": 223.11363636363637,
            "pressPressStandardDeviation": 163.13525931872482,
            "releaseReleaseMean": 223.47272727270186,
            "releaseReleaseStandardDeviation": 233.56514689382186,
            "releasePressMean": 128.40681818195364,
            "releasePressStandardDeviation": 163.01653703762722,
            "backspaceCount": 2,
        },
    },
    {
        "timestamp": "2025-07-03T22:35:14.739Z",
        "features": {
            "holdTimeMean": 79.23333333329194,
            "holdTimeStandardDeviation": 19.595498166363527,
            "pressPressMean": 158.39032258063315,
            "pressPressStandardDeviation": 95.85528489622763,
            "releaseReleaseMean": 158.2209677419535,
            "releaseReleaseStandardDeviation": 94.16501062115232,
            "releasePressMean": 78.94838709681625,
            "releasePressStandardDeviation": 98.14726095724276,
            "backspaceCount": 2,
        },
    },
    {
        "timestamp": "2025-07-03T22:35:24.739Z",
        "features": {
            "holdTimeMean": 87.93064516118818,
            "holdTimeStandardDeviation": 52.42488017968451,
            "pressPressMean": 158.1327868852398,
            "pressPressStandardDeviation": 80.31051762022345,
            "releaseReleaseMean": 158.2196721311231,
            "releaseReleaseStandardDeviation": 108.54003841843364,
            "releasePressMean": 70.08360655746255,
            "releasePressStandardDeviation": 94.2395107872587,
            "backspaceCount": 7,
        },
    },
    {
        "timestamp": "2025-07-03T22:35:34.745Z",
        "features": {
            "holdTimeMean": 78.38245614036394,
            "holdTimeStandardDeviation": 33.8541626623831,
            "pressPressMean": 174.8982142857276,
            "pressPressStandardDeviation": 142.15976222833575,
            "releaseReleaseMean": 174.48214285714286,
            "releaseReleaseStandardDeviation": 154.25663516837463,
            "releasePressMean": 96.03392857140196,
            "releasePressStandardDeviation": 150.2904210059179,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:35:44.739Z",
        "features": {
            "holdTimeMean": 77.90000000012418,
            "holdTimeStandardDeviation": 20.552858682120313,
            "pressPressMean": 220.07727272728118,
            "pressPressStandardDeviation": 161.19607858298264,
            "releaseReleaseMean": 220.38181818183511,
            "releaseReleaseStandardDeviation": 165.15403560235475,
            "releasePressMean": 142.59999999988148,
            "releasePressStandardDeviation": 167.97451218617897,
            "backspaceCount": 2,
        },
    },
    {
        "timestamp": "2025-07-03T22:35:54.739Z",
        "features": {
            "holdTimeMean": 37.360000000149014,
            "holdTimeStandardDeviation": 49.68222015964942,
            "pressPressMean": 2042.5749999997206,
            "pressPressStandardDeviation": 2915.2377871848203,
            "releaseReleaseMean": 2061.75,
            "releaseReleaseStandardDeviation": 2903.580978148909,
            "releasePressMean": 2015.5499999998137,
            "releasePressStandardDeviation": 2867.2268373230722,
            "backspaceCount": 1,
        },
    },
    {
        "timestamp": "2025-07-03T22:36:24.739Z",
        "features": {
            "holdTimeMean": 124.05000000004657,
            "holdTimeStandardDeviation": 68.43944142693742,
            "pressPressMean": 226.21428571428572,
            "pressPressStandardDeviation": 75.25823163311944,
            "releaseReleaseMean": 227.94285714280392,
            "releaseReleaseStandardDeviation": 169.79861461061213,
            "releasePressMean": 99.37142857137535,
            "releasePressStandardDeviation": 125.58158986973483,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:36:34.739Z",
        "features": {
            "holdTimeMean": 86.97719298231236,
            "holdTimeStandardDeviation": 22.05218662268695,
            "pressPressMean": 172.44642857142858,
            "pressPressStandardDeviation": 105.61947989107428,
            "releaseReleaseMean": 171.86964285712955,
            "releaseReleaseStandardDeviation": 106.01169732993755,
            "releasePressMean": 85.17857142870447,
            "releasePressStandardDeviation": 107.98015762883003,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:36:44.739Z",
        "features": {
            "holdTimeMean": 97.63571428560785,
            "holdTimeStandardDeviation": 45.94939703537579,
            "pressPressMean": 750,
            "pressPressStandardDeviation": 813.1942756808762,
            "releaseReleaseMean": 750.8076923076923,
            "releaseReleaseStandardDeviation": 815.686631476234,
            "releasePressMean": 650.9692307693454,
            "releasePressStandardDeviation": 821.668661307127,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:36:54.739Z",
        "features": {
            "holdTimeMean": 97.4333333329608,
            "holdTimeStandardDeviation": 16.932906818975688,
            "pressPressMean": 3283.75,
            "pressPressStandardDeviation": 1159.0187250412896,
            "releaseReleaseMean": 3295.5999999996275,
            "releaseReleaseStandardDeviation": 1188.6464991745863,
            "releasePressMean": 3188.75,
            "releasePressStandardDeviation": 1182.211827464735,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:37:04.739Z",
        "features": {
            "holdTimeMean": 95.0660000000894,
            "holdTimeStandardDeviation": 35.660053738803335,
            "pressPressMean": 185.6142857142781,
            "pressPressStandardDeviation": 121.79430918573863,
            "releaseReleaseMean": 184.64897959185194,
            "releaseReleaseStandardDeviation": 133.22397982726667,
            "releasePressMean": 90.22653061216127,
            "releasePressStandardDeviation": 120.09097380643101,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:37:14.739Z",
        "features": {
            "holdTimeMean": 89.76363636333157,
            "holdTimeStandardDeviation": 15.959089744153854,
            "pressPressMean": 124.90999999996275,
            "pressPressStandardDeviation": 46.22665056289737,
            "releaseReleaseMean": 122.6699999999255,
            "releaseReleaseStandardDeviation": 48.14222101752029,
            "releasePressMean": 34.890000000223516,
            "releasePressStandardDeviation": 49.978160786566285,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:49:28.854Z",
        "features": {
            "holdTimeMean": 185.73333333339542,
            "holdTimeStandardDeviation": 272.70095464894337,
            "pressPressMean": 309.7,
            "pressPressStandardDeviation": 327.7285462077215,
            "releaseReleaseMean": 177.6800000000745,
            "releaseReleaseStandardDeviation": 52.51920601008975,
            "releasePressMean": 103.239999999851,
            "releasePressStandardDeviation": 58.22987205828118,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:49:38.855Z",
        "features": {
            "holdTimeMean": 74.91499999997517,
            "holdTimeStandardDeviation": 19.304744520934445,
            "pressPressMean": 165.31525423731338,
            "pressPressStandardDeviation": 165.19995492778457,
            "releaseReleaseMean": 165.56101694914622,
            "releaseReleaseStandardDeviation": 157.27675038850182,
            "releasePressMean": 90.47457627121801,
            "releasePressStandardDeviation": 165.210067524689,
            "backspaceCount": 0,
        },
    },
    {
        "timestamp": "2025-07-03T22:49:48.854Z",
        "features": {
            "holdTimeMean": 85.81875000020955,
            "holdTimeStandardDeviation": 22.778095289200667,
            "pressPressMean": 179.1800000000745,
            "pressPressStandardDeviation": 89.7655613246614,
            "releaseReleaseMean": 178.14666666674117,
            "releaseReleaseStandardDeviation": 101.95918557848609,
            "releasePressMean": 91.61333333315949,
            "releasePressStandardDeviation": 99.92575005365084,
            "backspaceCount": 0,
        },
    },
]

# %% [markdown]
# ## Keep only the features

# %%
training_data = [item["features"] for item in training_data]
training_data[:2]
# Out:
# [{'holdTimeMean': 117.08888888928212,
#   'holdTimeStandardDeviation': 92.68943012852175,
#   'pressPressMean': 183.4470588235075,
#   'pressPressStandardDeviation': 82.9403258195698,
#   'releaseReleaseMean': 160.4470588235075,
#   'releaseReleaseStandardDeviation': 100.67415332190842,
#   'releasePressMean': 64.57058823492159,
#   'releasePressStandardDeviation': 94.257518033792,
#   'backspaceCount': 0},
#  {'holdTimeMean': 91.02499999987104,
#   'holdTimeStandardDeviation': 35.15900506626477,
#   'pressPressMean': 190.64313725488006,
#   'pressPressStandardDeviation': 126.63483763130077,
#   'releaseReleaseMean': 190.10196078433563,
#   'releaseReleaseStandardDeviation': 129.68660299383995,
#   'releasePressMean': 98.91372549033487,
#   'releasePressStandardDeviation': 134.6274474533896,
#   'backspaceCount': 3}]

# %% [markdown]
# ## Visualize the data

# %%
import pandas as pd

df = pd.DataFrame(training_data)
df.head(5)
# Out:
#    holdTimeMean  holdTimeStandardDeviation  pressPressMean  \
# 0    117.088889                  92.689430      183.447059
# 1     91.025000                  35.159005      190.643137
# 2     76.989130                  24.624452      218.875556
# 3     84.618000                  30.760342      197.069388
# 4     83.384906                  20.855440      185.150000
#
#    pressPressStandardDeviation  releaseReleaseMean  \
# 0                    82.940326          160.447059
# 1                   126.634838          190.101961
# 2                   166.029216          219.566667
# 3                   124.396205          196.185714
# 4                    79.420404          184.590385
#
#    releaseReleaseStandardDeviation  releasePressMean  \
# 0                       100.674153         64.570588
# 1                       129.686603         98.913725
# 2                       171.079022        141.931111
# 3                       133.213377        112.310204
# ...

# %%
x = df.values
x.shape
# Out:
# (50, 9)

# %% [markdown]
# ## Dimensionality reduction

# %%
import numpy as np


x_inference = np.array(
    [
        68.66666666651145,  # holdTimeMean
        13.008202540473416,  # holdTimeStandardDeviation
        2461,  # pressPressMean
        743.876333808248,  # pressPressStandardDeviation
        2385.4000000001397,  # releasePressMean
        736.8052659963826,  # releasePressStandardDeviation
        2453.0999999999767,  # releaseReleaseMean
        718.5619110417367,  # releaseReleaseStandardDeviation
        0,  # backspaceCount
    ]
)
x_inference = x_inference.reshape(1, -1)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
x_pca = pca.fit_transform(x)
x_inference_pca = pca.transform(x_inference)

# %% [markdown]
# ## Plot the data

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

plt.scatter(x_pca[:, 0], x_pca[:, 1], alpha=0.5, label="Training data")
plt.scatter(
    x_inference_pca[0, 0], x_inference_pca[0, 1], color="red", label="New data point"
)
plt.title("PCA of keystroke dynamics")
plt.xlabel("Principal component 1")
plt.ylabel("Principal component 2")
plt.legend()
plt.grid()
plt.show()
